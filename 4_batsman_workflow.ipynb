# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
class BatsmanState(TypedDict):

    runs: int
    fours:int
    six: int
    balls: int

    sr:float
    bpb: float
    boundary_percentage: float
    summary: str

# %%
def calulate_sr(state:BatsmanState):

    sr =(state['runs']/state['ball'])*100
    
    state['sr'] = sr

    return state

# %%
def calculate_bpb(state:BatsmanState):

   bpb = state['balls'] / (state['fours'] + state['six'])

   state[bpb] = bpb

   return state

# %%
def calculate_boundary_percentage(state:BatsmanState):

    calculate_boundary_percentage = ((state['fours'] * 4) + (state['six'] * 6)/state['runs'])*100

    state['boundary_percentage'] = calculate_boundary_percentage

    return state

# %%
def summary(state:BatsmanState):
    
    graph.add

# %%
graph = StateGraph(BatsmanState)

graph.add_node('calculate_sr', calculate_sr)
graph.add_node('calculate_bpb', calculate_bpb)
graph.add_node('calculate_boundary_percent', calculate_boundary_percent)
graph.add_node('summary', summary)
