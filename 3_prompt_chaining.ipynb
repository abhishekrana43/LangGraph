# %%
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    
    title:str
    outline:str
    content:str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call LLM gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    #update
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title -{title} using the following outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content
    
    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {
    "title": "Rise of AI in India",
    "outline": "",
    "content": ""
}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "I. Introduction\n    A. Brief overview of artificial intelligence (AI) and its increasing relevance in India\n    B. Importance of AI in various sectors such as healthcare, finance, agriculture, and manufacturing\n    C. Thesis statement – The rise of AI in India is revolutionizing the way businesses operate and paving the way for innovation and growth\n\nII. Historical background of AI in India\n    A. Evolution of AI technologies in India over the years\n    B. Key milestones and advancements in AI research and development in the country\n    C. Contribution of Indian companies and educational institutions to the development of AI technologies\n\nIII. Current landscape of AI in India\n    A. Overview of current AI start-ups and companies in India\n    B. Key industries leveraging AI technologies in India\n    C. Government initiatives and policies promoting the adoption of AI in the country\n\nIV. Impact of AI on Indian economy and society\n    A. Role of AI in enhancing productivity and efficiency in businesses\n    B. AI's potential to create new job opportunities and drive economic growth in India\n    C. Ethical considerations and challenges surrounding the use of AI in India\n\nV. Future prospects of AI in India\n    A. Predictions for the growth and adoption of AI technologies in India\n    B. Opportunities for collaboration and partnerships between Indian and international AI companies\n    C. Potential challenges and risks that need to be addressed for the successful integration of AI in India\n\nVI. Case studies and success stories\n    A. Examples of Indian companies using AI to drive innovation and growth\n    B. Impact of AI on specific industries in India such as healthcare, finance, and agriculture\n    C. Lessons learned and best practices for implementing AI technologies in Indian businesses\n\nVII. Conclusion\n    A. Recap of the rise of AI in India and its transformative impact on the country\n    B. Importance of continued investment and support for AI research and development in India\n    C. Call to action for businesses and policymakers to embrace AI technologies and drive innovation in the country.", 'content': "Artificial Intelligence (AI) is revolutionizing the way businesses operate in India, paving the way for innovation and growth across various sectors such as healthcare, finance, agriculture, and manufacturing. The rise of AI in India is not just a trend but a significant shift that is transforming the country's economy and society. In this blog, we will explore the historical background of AI in India, the current landscape, its impact on the economy and society, future prospects, as well as case studies and success stories of AI implementation in the country.\n\nHistorical Background of AI in India\nAI technologies in India have evolved over the years, with key milestones and advancements in research and development. Indian companies and educational institutions have made significant contributions to the development of AI technologies, keeping pace with global trends and innovations in the field.\n\nCurrent Landscape of AI in India\nThere is a growing number of AI start-ups and companies in India, with key industries such as healthcare, finance, and agriculture leveraging AI technologies to streamline operations and enhance efficiency. Government initiatives and policies are also promoting the adoption of AI in the country, supporting the growth of the AI ecosystem in India.\n\nImpact of AI on Indian Economy and Society\nAI is enhancing productivity and efficiency in businesses, creating new job opportunities, and driving economic growth in India. However, there are ethical considerations and challenges surrounding the use of AI that need to be addressed to ensure responsible and ethical AI deployment in the country.\n\nFuture Prospects of AI in India\nPredictions for the growth and adoption of AI technologies in India are positive, with opportuniti ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief overview of artificial intelligence (AI) and its increasing relevance in India
#     B. Importance of AI in various sectors such as healthcare, finance, agriculture, and manufacturing
#     C. Thesis statement – The rise of AI in India is revolutionizing the way businesses operate and paving the way for innovation and growth
#
# II. Historical background of AI in India
#     A. Evolution of AI technologies in India over the years
#     B. Key milestones and advancements in AI research and development in the country
#     C. Contribution of Indian companies and educational institutions to the development of AI technologies
#
# III. Current landscape of AI in India
#     A. Overview of current AI start-ups and companies in India
#     B. Key industries leveraging AI technologies in India
#     C. Government initiatives and policies promoting the adoption of AI in the country
#
# IV. Impact of AI on Indian economy and society
#     A. Role of AI in enhancing productivity and efficiency in businesses
#     B. AI's potential to create new job opportunities and drive economic growth in India
#     C. Ethical considerations and challenges surrounding the use of AI in India
#
# V. Future prospects of AI in India
#     A. Predictions for the growth and adoption of AI technologies in India
#     B. Opportunities for collaboration and partnerships between Indian and international AI companies
#     C. Potential challenges and risks that need to be addressed for the successful integration of AI in India
#
# VI. Case studies and success stories
#     A. Examples of Indian companies using AI to drive innovation and growth
#     B. Impact of AI on specific industries in India such as healthcare, finance, and agriculture
#     C. Lessons learned and best practices for implementing AI technologies in Indian businesses
#
# VII. Conclusion
#     A. Recap of the rise of AI in India and its transformative impact on the country
#     B. Importance of continued investment and support for AI research and development in India
#     C. Call to action for businesses and policymakers to embrace AI technologies and drive innovation in the country.

# %%
print(final_state['content'])
# Out:
# Artificial Intelligence (AI) is revolutionizing the way businesses operate in India, paving the way for innovation and growth across various sectors such as healthcare, finance, agriculture, and manufacturing. The rise of AI in India is not just a trend but a significant shift that is transforming the country's economy and society. In this blog, we will explore the historical background of AI in India, the current landscape, its impact on the economy and society, future prospects, as well as case studies and success stories of AI implementation in the country.
#
# Historical Background of AI in India
# AI technologies in India have evolved over the years, with key milestones and advancements in research and development. Indian companies and educational institutions have made significant contributions to the development of AI technologies, keeping pace with global trends and innovations in the field.
#
# Current Landscape of AI in India
# There is a growing number of AI start-ups and companies in India, with key industries such as healthcare, finance, and agriculture leveraging AI technologies to streamline operations and enhance efficiency. Government initiatives and policies are also promoting the adoption of AI in the country, supporting the growth of the AI ecosystem in India.
#
# Impact of AI on Indian Economy and Society
# AI is enhancing productivity and efficiency in businesses, creating new job opportunities, and driving economic growth in India. However, there are ethical considerations and challenges surrounding the use of AI that need to be addressed to ensure responsible and ethical AI deployment in the country.
#
# Future Prospects of AI in India
# Predictions for the growth and adoption of AI technologies in India are positive, with opportunities for collaboration and partnerships between Indian and international AI companies. However, there are potential challenges and risks that need to be addressed for successful integration of AI in India, such as data privacy, regulatory frameworks, and ethical considerations.
#
# Case Studies and Success Stories
# There are numerous examples of Indian companies using AI to drive innovation and growth, with AI making a significant impact on specific industries such as healthcare, finance, and agriculture. Lessons learned and best practices for implementing AI technologies in Indian businesses can guide others in harnessing the power of AI for sustainable growth and development.
#
# In conclusion, the rise of AI in India is transforming the country's economy and society, with continued investment and support for AI research and development critical for sustained growth and innovation. Businesses and policymakers need to embrace AI technologies and drive innovation to capitalize on the opportunities that AI offers for a brighter and more prosperous future for India.
